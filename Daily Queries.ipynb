# %%
import pymongo
import datetime
import mysql.connector
import time
import pandas as pd

# %%
#connect mysql
mydb = mysql.connector.connect(
    host="localhost",       # host
    user="root",    # username
    passwd="password",   # password 
    database= "stackexchange_cs", # database
)

# %%
#connect mongodb
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
mongodb = mongo_client["cs_stackexchange"]

# %%
# get the sql query result
def getSQLResult(query):
    cursor = mydb.cursor()
    start = time.perf_counter()
    cursor.execute(query)
    cost = time.perf_counter() - start
    result = cursor.fetchall()
    df = pd.DataFrame(result, columns = cursor.column_names)
    cursor.close()

    return df, cost

# %%
def getMongoResult(query):
    start = time.perf_counter()
    result = query()
    cost = time.perf_counter() - start

    list_result = list(result)
    df = pd.DataFrame(list_result)

    return df, cost

# %% [markdown]
# ### Get monthly new users

# %%
sql = '''
    SELECT DATE_FORMAT(CreationDate, '%Y-%m') AS date, COUNT(*) AS count
    FROM Users
    GROUP BY date
    ORDER BY date;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#       date  count
# 0  2012-03    820
# 1  2012-04    443
# 2  2012-05    359
# 3  2012-06    303
# 4  2012-07    282

# %%
sql_cost
# Out:
# 0.31984749999999984

# %%
query = lambda: mongodb.Users.aggregate( [
    {
    '$group': {
      '_id': {
        '$dateToString': {
          'format': "%Y-%m",
          'date': "$CreationDate",
        },
      },
      'count': {
        '$sum': 1,
      },
    },
  },
  {
    '$sort': {
      '_id': 1,
    },
  }])

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#        _id  count
# 0  2012-03    820
# 1  2012-04    443
# 2  2012-05    359
# 3  2012-06    303
# 4  2012-07    282

# %%
mongo_cost
# Out:
# 0.8562171000000003

# %% [markdown]
# ### Get daily new users

# %%
sql = '''
    SELECT DATE_FORMAT(CreationDate, '%Y-%m-%d') AS date, COUNT(*) AS count
    FROM Users
    GROUP BY date
    ORDER BY date;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#          date  count
# 0  2012-03-06    100
# 1  2012-03-07     42
# 2  2012-03-08     15
# 3  2012-03-09      6
# 4  2012-03-10     16

# %%
sql_cost
# Out:
# 0.1967863999999997

# %%
query = lambda: mongodb['Users'].aggregate([
    {
    '$group': {
      '_id': {
        '$dateToString': {
          'format': "%Y-%m-%d",
          'date': "$CreationDate",
        },
      },
      'count': {
        '$sum': 1,
      },
    },
  },
  {
    '$sort': {
      '_id': 1,
    },
  }])

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#           _id  count
# 0  2012-03-06    100
# 1  2012-03-07     42
# 2  2012-03-08     15
# 3  2012-03-09      6
# 4  2012-03-10     16

# %%
mongo_cost
# Out:
# 0.37692050000000066

# %% [markdown]
# ### Select posts by last activity time

# %%
#Take '2012-03-06' as an example
sql = '''
    SELECT *
    FROM Posts
    WHERE DATE_FORMAT(LastActivityDate, '%Y-%m-%d') = '2012-03-06';
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#    Id  PostTypeId AcceptedAnswerId  ParentId        CreationDate DeletionDate  \
# 0   6           2             None       3.0 2012-03-06 19:19:20         None
# 1   7           1             None       NaN 2012-03-06 19:34:23         None
# 2   9           2             None       7.0 2012-03-06 19:44:18         None
# 3  10           2             None       3.0 2012-03-06 19:48:00         None
# 4  12           2             None       5.0 2012-03-06 19:55:00         None
#
#    Score  ViewCount                                               Body  \
# 0     24        NaN  <p>In comparison to other comparison-based sor...
# 1     15      376.0  <p>When placing geometric objects in a quadtre...
# 2      8        NaN  <p>Assuming you are storing a reference, not t...
# 3     41        NaN  <p>I think one of the main reasons why QuickSo...
# 4     15        NaN  <p>In a truly "cooperative" setting, and if th...
#
#    OwnerUserId  ...        LastEditDate    LastActivityDate  \
# 0         41.0  ... 2012-03-06 22:18:33 2012-03-06 22:18:33
# 1         11.0  ... 2012-03-06 19:47:07 2012-03-06 20:22:06
# 2         44.0  ...                 NaT 2012-03-06 19:44:18
# 3         29.0  ...                 NaT 2012-03-06 19:48:00
# 4         43.0  ...                 NaT 2012-03-06 19:55:00
#
#                                                Title  \
# 0                                               None
# 1  Which method is preferred for storing large ge...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 Tags AnswerCount CommentCount  \
# 0                                               None         NaN           13
# 1  <graphics><data-structures><computational-geom...         2.0            5
# 2                                               None         NaN            1
# 3                                               None         NaN            6
# 4                                               None         NaN            0
#
#   FavoriteCount  ClosedDate  CommunityOwnedDate ContentLicense
# 0          None        None                None   CC BY-SA 3.0
# 1          None        None                None   CC BY-SA 3.0
# 2          None        None                None   CC BY-SA 3.0
# 3          None        None                None   CC BY-SA 3.0
# 4          None        None                None   CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.015488899999999362

# %%
query = lambda: mongodb.Posts.find(
            {
          "$expr": {
            "$regexMatch": {
              "input":{ '$dateToString': {
                      'format': "%Y-%m-%d",
                      'date': "$LastActivityDate",
                    }},
              "regex": '2012-03-06'
            }
          }
        })

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId AcceptedAnswerId  ParentId  \
# 0  6551e8acdb0b505f45a61a88       6           2             None       3.0
# 1  6551e8acdb0b505f45a61a89       7           1             None       NaN
# 2  6551e8acdb0b505f45a61a8a       9           2             None       7.0
# 3  6551e8acdb0b505f45a61a8b      10           2             None       3.0
# 4  6551e8acdb0b505f45a61a8d      12           2             None       5.0
#
#              CreationDate  Score  ViewCount  \
# 0 2012-03-06 19:19:20.237     24        NaN
# 1 2012-03-06 19:34:22.793     15      376.0
# 2 2012-03-06 19:44:17.600      8        NaN
# 3 2012-03-06 19:48:00.343     41        NaN
# 4 2012-03-06 19:54:59.633     15        NaN
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>In comparison to other comparison-based sor...         41.0  ...
# 1  <p>When placing geometric objects in a quadtre...         11.0  ...
# 2  <p>Assuming you are storing a reference, not t...         44.0  ...
# 3  <p>I think one of the main reasons why QuickSo...         29.0  ...
# 4  <p>In a truly "cooperative" setting, and if th...         43.0  ...
#
#              LastEditDate        LastActivityDate  \
# 0 2012-03-06 22:18:33.027 2012-03-06 22:18:33.027
# 1 2012-03-06 19:47:07.427 2012-03-06 20:22:05.510
# 2                     NaT 2012-03-06 19:44:17.600
# 3                     NaT 2012-03-06 19:48:00.343
# 4                     NaT 2012-03-06 19:54:59.633
#
#                                                Title  \
# 0
# 1  Which method is preferred for storing large ge...
# 2
# 3
# 4
#
#                                                 Tags AnswerCount  \
# 0                                                 []         NaN
# 1  [graphics, data-structures, computational-geom...         2.0
# 2                                                 []         NaN
# 3                                                 []         NaN
# 4                                                 []         NaN
#
#    CommentCount  FavoriteCount ClosedDate CommunityOwnedDate  \
# 0            13           None       None               None
# 1             5           None       None               None
# 2             1           None       None               None
# 3             6           None       None               None
# 4             0           None       None               None
#
#                                             Comments
# 0  [{'CommentId': 14, 'Score': 0, 'Text': 'And ye...
# 1  [{'CommentId': 26, 'Score': 1, 'Text': 'Certai...
# 2  [{'CommentId': 29, 'Score': 0, 'Text': 'Thanks...
# 3  [{'CommentId': 93, 'Score': 6, 'Text': 'That's...
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
mongo_cost
# Out:
# 0.00045659999999969614

# %% [markdown]
# ### Select posts by creation time

# %%
#Take '2012-03-06' as an example
sql = '''
    SELECT *
    FROM Posts
    WHERE DATE_FORMAT(CreationDate, '%Y-%m-%d') = '2012-03-06';
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId  ParentId        CreationDate  \
# 0   2           1              28.0       NaN 2012-03-06 19:06:06
# 1   3           1              90.0       NaN 2012-03-06 19:11:07
# 2   5           1              12.0       NaN 2012-03-06 19:17:48
# 3   6           2               NaN       3.0 2012-03-06 19:19:20
# 4   7           1               NaN       NaN 2012-03-06 19:34:23
#
#   DeletionDate  Score  ViewCount  \
# 0         None     19     1343.0
# 1         None    380   344624.0
# 2         None     19     1736.0
# 3         None     24        NaN
# 4         None     15      376.0
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>The set difference operator (e.g., <code>EX...          5.0  ...
# 1  <p>In a standard algorithms course we are taug...         24.0  ...
# 2  <p>Many operating systems references say that ...         40.0  ...
# 3  <p>In comparison to other comparison-based sor...         41.0  ...
# 4  <p>When placing geometric objects in a quadtre...         11.0  ...
#
#          LastEditDate    LastActivityDate  \
# 0 2012-04-02 15:35:06 2013-05-29 00:50:35
# 1 2020-07-30 12:01:28 2020-07-31 22:29:47
# 2 2012-04-07 13:42:43 2012-04-09 22:15:05
# 3 2012-03-06 22:18:33 2012-03-06 22:18:33
# 4 2012-03-06 19:47:07 2012-03-06 20:22:06
#
#                                                Title  \
# 0  Does the 'difference' operation add expressive...
# 1  Why is quicksort better than other sorting alg...
# 2  Does cooperative scheduling suspend processes ...
# 3                                               None
# 4  Which method is preferred for storing large ge...
#
#                                                 Tags AnswerCount CommentCount  \
# 0  <database-theory><relational-algebra><finite-m...         2.0            2
# 1                              <algorithms><sorting>        12.0           18
# 2            <operating-systems><process-scheduling>         4.0            2
# 3                                               None         NaN           13
# 4  <graphics><data-structures><computational-geom...         2.0            5
#
#   FavoriteCount  ClosedDate  CommunityOwnedDate  ContentLicense
# 0           NaN        None                None    CC BY-SA 3.0
# 1           NaN        None                None    CC BY-SA 3.0
# 2           0.0        None                None    CC BY-SA 3.0
# 3           NaN        None                None    CC BY-SA 3.0
# 4           NaN        None                None    CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.0014447999999998018

# %%
query = lambda: mongodb.Posts.find({
          "$expr": {
            "$regexMatch": {
              "input":{ '$dateToString': {
                      'format': "%Y-%m-%d",
                      'date': "$CreationDate",
                    }},
              "regex": '2012-03-06'
            }
          }
        })

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId  AcceptedAnswerId  ParentId  \
# 0  6551e8acdb0b505f45a61a85       2           1              28.0       NaN
# 1  6551e8acdb0b505f45a61a86       3           1              90.0       NaN
# 2  6551e8acdb0b505f45a61a87       5           1              12.0       NaN
# 3  6551e8acdb0b505f45a61a88       6           2               NaN       3.0
# 4  6551e8acdb0b505f45a61a89       7           1               NaN       NaN
#
#              CreationDate  Score  ViewCount  \
# 0 2012-03-06 19:06:05.667     19     1343.0
# 1 2012-03-06 19:11:07.127    380   344624.0
# 2 2012-03-06 19:17:48.460     19     1736.0
# 3 2012-03-06 19:19:20.237     24        NaN
# 4 2012-03-06 19:34:22.793     15      376.0
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>The set difference operator (e.g., <code>EX...          5.0  ...
# 1  <p>In a standard algorithms course we are taug...         24.0  ...
# 2  <p>Many operating systems references say that ...         40.0  ...
# 3  <p>In comparison to other comparison-based sor...         41.0  ...
# 4  <p>When placing geometric objects in a quadtre...         11.0  ...
#
#              LastEditDate        LastActivityDate  \
# 0 2012-04-02 15:35:05.827 2013-05-29 00:50:34.590
# 1 2020-07-30 12:01:27.630 2020-07-31 22:29:46.523
# 2 2012-04-07 13:42:43.093 2012-04-09 22:15:05.277
# 3 2012-03-06 22:18:33.027 2012-03-06 22:18:33.027
# 4 2012-03-06 19:47:07.427 2012-03-06 20:22:05.510
#
#                                                Title  \
# 0  Does the 'difference' operation add expressive...
# 1  Why is quicksort better than other sorting alg...
# 2  Does cooperative scheduling suspend processes ...
# 3
# 4  Which method is preferred for storing large ge...
#
#                                                 Tags AnswerCount  \
# 0  [database-theory, relational-algebra, finite-m...         2.0
# 1                              [algorithms, sorting]        12.0
# 2            [operating-systems, process-scheduling]         4.0
# 3                                                 []         NaN
# 4  [graphics, data-structures, computational-geom...         2.0
#
#    CommentCount  FavoriteCount  ClosedDate CommunityOwnedDate  \
# 0             2            NaN        None               None
# 1            18            NaN        None               None
# 2             2            0.0        None               None
# 3            13            NaN        None               None
# 4             5            NaN        None               None
#
#                                             Comments
# 0  [{'CommentId': 8, 'Score': 2, 'Text': 'To show...
# 1  [{'CommentId': 11, 'Score': 4, 'Text': 'Merge ...
# 2  [{'CommentId': 104, 'Score': 0, 'Text': 'This ...
# 3  [{'CommentId': 14, 'Score': 0, 'Text': 'And ye...
# 4  [{'CommentId': 26, 'Score': 1, 'Text': 'Certai...
#
# [5 rows x 21 columns]

# %%
mongo_cost
# Out:
# 0.0001265999999997547

# %% [markdown]
# ### Select posts by viewcount

# %%
#Take '68' as an example
sql = '''
    SELECT *
    FROM Posts
    WHERE ViewCount = 68;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#       Id  PostTypeId  AcceptedAnswerId ParentId        CreationDate  \
# 0   2064           1            2072.0     None 2012-05-25 04:33:49
# 1   9306           1            9316.0     None 2013-01-30 13:25:23
# 2  10482           1               NaN     None 2013-03-12 13:46:05
# 3  11872           1               NaN     None 2013-05-08 00:29:13
# 4  13418           1           13430.0     None 2013-07-24 14:07:52
#
#   DeletionDate  Score  ViewCount  \
# 0         None      3         68
# 1         None      0         68
# 2         None      0         68
# 3         None      1         68
# 4         None      2         68
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I need to recover a data block from a repea...       1642.0  ...
# 1  <p>So say I have a task like this:</p>&#xA;&#x...       5281.0  ...
# 2  <p>Suppose that there is some graph, with $n$ ...       7243.0  ...
# 3  <p>Is there a common code metric for "code red...       1829.0  ...
# 4  <p>I'm trying to create simple tokenizer to tr...       9325.0  ...
#
#          LastEditDate    LastActivityDate  \
# 0 2012-05-25 11:53:59 2012-05-25 11:53:59
# 1                 NaT 2013-01-30 16:26:46
# 2                 NaT 2013-03-12 13:46:05
# 3 2013-05-09 01:46:25 2013-05-09 01:46:25
# 4 2013-07-24 15:48:59 2013-07-25 08:41:27
#
#                                                Title  \
# 0                 Block detection in repeated stream
# 1  Clarification for a class of Turing machine pr...
# 2  The name of "finding the path of a graph that ...
# 3    Code metric for code redundancy or code cloning
# 4                    Tokenizer and complex operators
#
#                                                 Tags AnswerCount CommentCount  \
# 0  <algorithms><online-algorithms><communication-...           1            0
# 1                                  <turing-machines>           1            5
# 2                        <complexity-theory><graphs>           0            3
# 3            <reference-request><empirical-research>           0            5
# 4                                          <parsers>           1            3
#
#   FavoriteCount          ClosedDate  CommunityOwnedDate ContentLicense
# 0          None                 NaT                None   CC BY-SA 3.0
# 1          None                 NaT                None   CC BY-SA 3.0
# 2          None 2016-07-05 08:17:58                None   CC BY-SA 3.0
# 3          None                 NaT                None   CC BY-SA 3.0
# 4          None                 NaT                None   CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.07485959999999992

# %%
query = lambda: mongodb.Posts.find({"ViewCount" : 68})

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId  AcceptedAnswerId ParentId  \
# 0  6551e8acdb0b505f45a621b1    2064           1            2072.0     None
# 1  6551e8acdb0b505f45a62ff7    9306           1            9316.0     None
# 2  6551e8acdb0b505f45a633db   10482           1               NaN     None
# 3  6551e8acdb0b505f45a63858   11872           1               NaN     None
# 4  6551e8acdb0b505f45a63d21   13418           1           13430.0     None
#
#              CreationDate  Score  ViewCount  \
# 0 2012-05-25 04:33:48.567      3         68
# 1 2013-01-30 13:25:23.467      0         68
# 2 2013-03-12 13:46:05.437      0         68
# 3 2013-05-08 00:29:13.067      1         68
# 4 2013-07-24 14:07:52.047      2         68
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I need to recover a data block from a repea...       1642.0  ...
# 1  <p>So say I have a task like this:</p>\n\n<blo...       5281.0  ...
# 2  <p>Suppose that there is some graph, with $n$ ...       7243.0  ...
# 3  <p>Is there a common code metric for "code red...       1829.0  ...
# 4  <p>I'm trying to create simple tokenizer to tr...       9325.0  ...
#
#          LastActivityDate                                              Title  \
# 0 2012-05-25 11:53:58.550                 Block detection in repeated stream
# 1 2013-01-30 16:26:46.157  Clarification for a class of Turing machine pr...
# 2 2013-03-12 13:46:05.437  The name of "finding the path of a graph that ...
# 3 2013-05-09 01:46:25.000    Code metric for code redundancy or code cloning
# 4 2013-07-25 08:41:26.530                    Tokenizer and complex operators
#
#                                                 Tags AnswerCount CommentCount  \
# 0  [algorithms, online-algorithms, communication-...           1            0
# 1                                  [turing-machines]           1            5
# 2                        [complexity-theory, graphs]           0            3
# 3            [reference-request, empirical-research]           0            5
# 4                                          [parsers]           1            3
#
#    FavoriteCount              ClosedDate CommunityOwnedDate  \
# 0           None                     NaT               None
# 1           None                     NaT               None
# 2           None 2016-07-05 08:17:58.053               None
# 3           None                     NaT               None
# 4           None                     NaT               None
#
#                                             Comments  \
# 0                                                NaN
# 1  [{'CommentId': 17893, 'Score': 1, 'Text': 'The...
# 2  [{'CommentId': 20559, 'Score': 0, 'Text': 'oh ...
# 3  [{'CommentId': 24799, 'Score': 1, 'Text': 'loo...
# 4  [{'CommentId': 28411, 'Score': 2, 'Text': 'Up ...
#
#                                            PostLinks
# 0                                                NaN
# 1                                                NaN
# 2  [{'PostLinkId': 174965, 'CreationDate': 2013-0...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 22 columns]

# %%
mongo_cost
# Out:
# 0.00010890000000074451

# %% [markdown]
# ### Select posts by score

# %%
#Take '2' as an example
sql = '''
    SELECT *
    FROM Posts
    WHERE Score = 2;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#     Id  PostTypeId  AcceptedAnswerId  ParentId        CreationDate  \
# 0   30           2               NaN      27.0 2012-03-06 22:09:53
# 1  193           2               NaN     163.0 2012-03-10 12:08:48
# 2  211           2               NaN     196.0 2012-03-10 20:56:45
# 3  228           2               NaN     227.0 2012-03-12 00:06:03
# 4  229           2               NaN     227.0 2012-03-12 01:31:42
#
#   DeletionDate  Score  ViewCount  \
# 0         None      2        NaN
# 1         None      2        NaN
# 2         None      2        NaN
# 3         None      2        NaN
# 4         None      2        NaN
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>You may want to have a look at <a href="htt...         21.0  ...
# 1  <p>Since permuting two rows within a single bl...         24.0  ...
# 2  <p>This doesn't fit case 3 exactly, but I don'...         71.0  ...
# 3  <p>You get fewer special cases.  In many situa...         15.0  ...
# 4  <p>Having links to the parent directory makes ...         29.0  ...
#
#          LastEditDate    LastActivityDate Title  Tags AnswerCount  \
# 0                 NaT 2012-03-06 22:09:53  None  None         NaN
# 1 2012-03-10 12:20:38 2012-03-10 12:20:38  None  None         NaN
# 2                 NaT 2012-03-10 20:56:45  None  None         NaN
# 3 2012-03-12 18:06:47 2012-03-12 18:06:47  None  None         NaN
# 4                 NaT 2012-03-12 01:31:42  None  None         NaN
#
#   CommentCount FavoriteCount  ClosedDate  CommunityOwnedDate  ContentLicense
# 0            2           NaN         NaT                 NaT    CC BY-SA 3.0
# 1            0           NaN         NaT                 NaT    CC BY-SA 3.0
# 2            2           NaN         NaT                 NaT    CC BY-SA 3.0
# 3            7           NaN         NaT                 NaT    CC BY-SA 3.0
# 4            3           NaN         NaT                 NaT    CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.008162499999999184

# %%
query = lambda: mongodb.Posts.find({"Score" : 2})

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId  AcceptedAnswerId  ParentId  \
# 0  6551e8acdb0b505f45a61a9e      30           2               NaN      27.0
# 1  6551e8acdb0b505f45a61b38     193           2               NaN     163.0
# 2  6551e8acdb0b505f45a61b48     211           2               NaN     196.0
# 3  6551e8acdb0b505f45a61b58     228           2               NaN     227.0
# 4  6551e8acdb0b505f45a61b59     229           2               NaN     227.0
#
#              CreationDate  Score  ViewCount  \
# 0 2012-03-06 22:09:52.677      2        NaN
# 1 2012-03-10 12:08:48.173      2        NaN
# 2 2012-03-10 20:56:44.693      2        NaN
# 3 2012-03-12 00:06:02.723      2        NaN
# 4 2012-03-12 01:31:42.280      2        NaN
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>You may want to have a look at <a href="htt...         21.0  ...
# 1  <p>Since permuting two rows within a single bl...         24.0  ...
# 2  <p>This doesn't fit case 3 exactly, but I don'...         71.0  ...
# 3  <p>You get fewer special cases.  In many situa...         15.0  ...
# 4  <p>Having links to the parent directory makes ...         29.0  ...
#
#          LastActivityDate Title Tags AnswerCount CommentCount  FavoriteCount  \
# 0 2012-03-06 22:09:52.677         []         NaN            2            NaN
# 1 2012-03-10 12:20:37.923         []         NaN            0            NaN
# 2 2012-03-10 20:56:44.693         []         NaN            2            NaN
# 3 2012-03-12 18:06:47.050         []         NaN            7            NaN
# 4 2012-03-12 01:31:42.280         []         NaN            3            NaN
#
#    ClosedDate  CommunityOwnedDate  \
# 0         NaT                 NaT
# 1         NaT                 NaT
# 2         NaT                 NaT
# 3         NaT                 NaT
# 4         NaT                 NaT
#
#                                             Comments PostLinks
# 0  [{'CommentId': 76, 'Score': 2, 'Text': 'And ho...       NaN
# 1                                                NaN       NaN
# 2  [{'CommentId': 542, 'Score': 1, 'Text': 'Writt...       NaN
# 3  [{'CommentId': 566, 'Score': 3, 'Text': 'If th...       NaN
# 4  [{'CommentId': 571, 'Score': 3, 'Text': 'Same ...       NaN
#
# [5 rows x 22 columns]

# %%
mongo_cost
# Out:
# 6.319999999959691e-05

# %% [markdown]
# ### Select posts which do not have an answer.

# %%
#Take '2' as an example
sql = '''
    SELECT *
    FROM Posts
    WHERE AnswerCount = 0;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#      Id  PostTypeId AcceptedAnswerId ParentId        CreationDate  \
# 0    81           1             None     None 2012-03-07 09:27:48
# 1   933           1             None     None 2012-04-01 04:01:58
# 2  1050           1             None     None 2012-04-05 02:59:27
# 3  1502           1             None     None 2012-04-25 13:44:46
# 4  1602           1             None     None 2012-04-30 23:20:10
#
#   DeletionDate  Score  ViewCount  \
# 0         None     10        133
# 1         None      4        111
# 2         None      0        121
# 3         None      8        582
# 4         None      8         84
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I am reading <a href="http://www.google.ch/...        125.0  ...
# 1  <p>I have asked a series of questions concerni...         69.0  ...
# 2  <blockquote>&#xA;  <p><strong>Possible Duplica...          NaN  ...
# 3  <p>Assume I want to insert elements $1$ to $n$...        220.0  ...
# 4  <p>My organization wants to maintain multiple ...       1038.0  ...
#
#          LastEditDate    LastActivityDate  \
# 0                 NaT 2012-03-07 09:27:48
# 1 2017-04-13 12:48:34 2012-04-01 13:42:33
# 2 2017-04-13 12:48:33 2012-04-05 03:20:46
# 3 2013-05-05 15:55:44 2013-05-05 15:55:44
# 4 2012-05-01 01:46:08 2012-05-01 01:46:08
#
#                                                Title  \
# 0  Applying the graph mining algorithm Leap Searc...
# 1  Computational power of nondeterministic type-2...
# 2               Multiples of n is a regular language
# 3  Predecessor query where the insertion order is...
# 4    Distributed Storage for Access and Preservation
#
#                                                 Tags AnswerCount CommentCount  \
# 0                                      <data-mining>           0            3
# 1                       <formal-languages><automata>           0            3
# 2              <formal-languages><regular-languages>           0            2
# 3                <data-structures><runtime-analysis>           0            6
# 4  <digital-preservation><distributed-systems><st...           0            1
#
#   FavoriteCount          ClosedDate  CommunityOwnedDate  ContentLicense
# 0           NaN                 NaT                None    CC BY-SA 3.0
# 1           NaN                 NaT                None    CC BY-SA 3.0
# 2           NaN 2012-04-05 14:34:37                None    CC BY-SA 3.0
# 3           NaN                 NaT                None    CC BY-SA 3.0
# 4           NaN                 NaT                None    CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.01651599999999931

# %%
query = lambda: mongodb.Posts.find({"AnswerCount" : 0})

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId AcceptedAnswerId ParentId  \
# 0  6551e8acdb0b505f45a61acf      81           1             None     None
# 1  6551e8acdb0b505f45a61de4     933           1             None     None
# 2  6551e8acdb0b505f45a61e4e    1050           1             None     None
# 3  6551e8acdb0b505f45a61fcc    1502           1             None     None
# 4  6551e8acdb0b505f45a6201f    1602           1             None     None
#
#              CreationDate  Score  ViewCount  \
# 0 2012-03-07 09:27:48.330     10        133
# 1 2012-04-01 04:01:58.047      4        111
# 2 2012-04-05 02:59:27.360      0        121
# 3 2012-04-25 13:44:46.220      8        582
# 4 2012-04-30 23:20:10.173      8         84
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I am reading <a href="http://www.google.ch/...        125.0  ...
# 1  <p>I have asked a series of questions concerni...         69.0  ...
# 2  <blockquote>\n  <p><strong>Possible Duplicate:...          NaN  ...
# 3  <p>Assume I want to insert elements $1$ to $n$...        220.0  ...
# 4  <p>My organization wants to maintain multiple ...       1038.0  ...
#
#          LastActivityDate                                              Title  \
# 0 2012-03-07 09:27:48.330  Applying the graph mining algorithm Leap Searc...
# 1 2012-04-01 13:42:32.693  Computational power of nondeterministic type-2...
# 2 2012-04-05 03:20:45.850               Multiples of n is a regular language
# 3 2013-05-05 15:55:44.163  Predecessor query where the insertion order is...
# 4 2012-05-01 01:46:07.983    Distributed Storage for Access and Preservation
#
#                                                 Tags AnswerCount CommentCount  \
# 0                                      [data-mining]           0            3
# 1                       [formal-languages, automata]           0            3
# 2              [formal-languages, regular-languages]           0            2
# 3                [data-structures, runtime-analysis]           0            6
# 4  [digital-preservation, distributed-systems, st...           0            1
#
#    FavoriteCount              ClosedDate  CommunityOwnedDate  \
# 0            NaN                     NaT                None
# 1            NaN                     NaT                None
# 2            NaN 2012-04-05 14:34:36.797                None
# 3            NaN                     NaT                None
# 4            NaN                     NaT                None
#
#                                             Comments  \
# 0  [{'CommentId': 173, 'Score': 0, 'Text': 'If I ...
# 1  [{'CommentId': 2204, 'Score': 0, 'Text': 'We a...
# 2  [{'CommentId': 2500, 'Score': 6, 'Text': 'poss...
# 3  [{'CommentId': 3860, 'Score': 1, 'Text': 'Plea...
# 4  [{'CommentId': 300906, 'Score': 0, 'Text': 'Th...
#
#                                            PostLinks
# 0                                                NaN
# 1  [{'PostLinkId': 7904, 'CreationDate': 2012-04-...
# 2  [{'PostLinkId': 9369, 'CreationDate': 2012-04-...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 22 columns]

# %%
mongo_cost
# Out:
# 9.070000000122036e-05

# %% [markdown]
# ### Select posts which do not have an accepted answer.

# %%
#Take '2' as an example
sql = '''
        SELECT *
        FROM Posts
        WHERE AcceptedAnswerId IS NULL;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#    Id  PostTypeId AcceptedAnswerId  ParentId        CreationDate DeletionDate  \
# 0   6           2             None       3.0 2012-03-06 19:19:20         None
# 1   7           1             None       NaN 2012-03-06 19:34:23         None
# 2   9           2             None       7.0 2012-03-06 19:44:18         None
# 3  10           2             None       3.0 2012-03-06 19:48:00         None
# 4  12           2             None       5.0 2012-03-06 19:55:00         None
#
#    Score  ViewCount                                               Body  \
# 0     24        NaN  <p>In comparison to other comparison-based sor...
# 1     15      376.0  <p>When placing geometric objects in a quadtre...
# 2      8        NaN  <p>Assuming you are storing a reference, not t...
# 3     41        NaN  <p>I think one of the main reasons why QuickSo...
# 4     15        NaN  <p>In a truly "cooperative" setting, and if th...
#
#    OwnerUserId  ...        LastEditDate    LastActivityDate  \
# 0         41.0  ... 2012-03-06 22:18:33 2012-03-06 22:18:33
# 1         11.0  ... 2012-03-06 19:47:07 2012-03-06 20:22:06
# 2         44.0  ...                 NaT 2012-03-06 19:44:18
# 3         29.0  ...                 NaT 2012-03-06 19:48:00
# 4         43.0  ...                 NaT 2012-03-06 19:55:00
#
#                                                Title  \
# 0                                               None
# 1  Which method is preferred for storing large ge...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 Tags AnswerCount CommentCount  \
# 0                                               None         NaN           13
# 1  <graphics><data-structures><computational-geom...         2.0            5
# 2                                               None         NaN            1
# 3                                               None         NaN            6
# 4                                               None         NaN            0
#
#   FavoriteCount  ClosedDate  CommunityOwnedDate  ContentLicense
# 0           NaN         NaT                 NaT    CC BY-SA 3.0
# 1           NaN         NaT                 NaT    CC BY-SA 3.0
# 2           NaN         NaT                 NaT    CC BY-SA 3.0
# 3           NaN         NaT                 NaT    CC BY-SA 3.0
# 4           NaN         NaT                 NaT    CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.0023933999999989908

# %%
query = lambda: mongodb.Posts.find({"AcceptedAnswerId" : None})

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId AcceptedAnswerId  ParentId  \
# 0  6551e8acdb0b505f45a61a88       6           2             None       3.0
# 1  6551e8acdb0b505f45a61a89       7           1             None       NaN
# 2  6551e8acdb0b505f45a61a8a       9           2             None       7.0
# 3  6551e8acdb0b505f45a61a8b      10           2             None       3.0
# 4  6551e8acdb0b505f45a61a8d      12           2             None       5.0
#
#              CreationDate  Score  ViewCount  \
# 0 2012-03-06 19:19:20.237     24        NaN
# 1 2012-03-06 19:34:22.793     15      376.0
# 2 2012-03-06 19:44:17.600      8        NaN
# 3 2012-03-06 19:48:00.343     41        NaN
# 4 2012-03-06 19:54:59.633     15        NaN
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>In comparison to other comparison-based sor...         41.0  ...
# 1  <p>When placing geometric objects in a quadtre...         11.0  ...
# 2  <p>Assuming you are storing a reference, not t...         44.0  ...
# 3  <p>I think one of the main reasons why QuickSo...         29.0  ...
# 4  <p>In a truly "cooperative" setting, and if th...         43.0  ...
#
#          LastActivityDate                                              Title  \
# 0 2012-03-06 22:18:33.027
# 1 2012-03-06 20:22:05.510  Which method is preferred for storing large ge...
# 2 2012-03-06 19:44:17.600
# 3 2012-03-06 19:48:00.343
# 4 2012-03-06 19:54:59.633
#
#                                                 Tags AnswerCount CommentCount  \
# 0                                                 []         NaN           13
# 1  [graphics, data-structures, computational-geom...         2.0            5
# 2                                                 []         NaN            1
# 3                                                 []         NaN            6
# 4                                                 []         NaN            0
#
#    FavoriteCount  ClosedDate  CommunityOwnedDate  \
# 0            NaN         NaT                 NaT
# 1            NaN         NaT                 NaT
# 2            NaN         NaT                 NaT
# 3            NaN         NaT                 NaT
# 4            NaN         NaT                 NaT
#
#                                             Comments PostLinks
# 0  [{'CommentId': 14, 'Score': 0, 'Text': 'And ye...       NaN
# 1  [{'CommentId': 26, 'Score': 1, 'Text': 'Certai...       NaN
# 2  [{'CommentId': 29, 'Score': 0, 'Text': 'Thanks...       NaN
# 3  [{'CommentId': 93, 'Score': 6, 'Text': 'That's...       NaN
# 4                                                NaN       NaN
#
# [5 rows x 22 columns]

# %%
mongo_cost
# Out:
# 8.379999999874599e-05

# %% [markdown]
# ### Find recently closed posts

# %%
#Show 10 recently closed posts.
sql = '''
    SELECT *
    FROM Posts
    ORDER BY ClosedDate DESC
    LIMIT 10;
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#        Id  PostTypeId AcceptedAnswerId ParentId        CreationDate  \
# 0  161781           1             None     None 2023-08-27 04:51:28
# 1  160197           1             None     None 2023-05-15 22:34:09
# 2  161778           1             None     None 2023-08-26 16:23:33
# 3  161733           1             None     None 2023-08-23 16:28:34
# 4  161703           1             None     None 2023-08-20 13:16:33
#
#   DeletionDate  Score  ViewCount  \
# 0         None     -2         39
# 1         None      1         18
# 2         None      0          9
# 3         None     -3         36
# 4         None      0         18
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>The algorithm assumes the graph is 3-colora...       162670  ...
# 1  <p>I'm working on implementing a puzzle board ...       160598  ...
# 2  <p>The input of my neural network consists of ...       162660  ...
# 3  <p>TL;DR: How can I make my final year project...       162599  ...
# 4  <p>I came across this question presented in a ...       162465  ...
#
#          LastEditDate    LastActivityDate  \
# 0 2023-08-27 04:53:59 2023-08-27 04:53:59
# 1                 NaT 2023-05-15 22:34:09
# 2                 NaT 2023-08-26 16:23:33
# 3 2023-08-24 18:30:13 2023-08-24 18:30:13
# 4                 NaT 2023-08-20 13:16:33
#
#                                                Title  \
# 0       Is this 3-colorability algorithm polynomial?
# 1  generating solvable puzzles for a Double-Choco...
# 2  What Model to Choose for a NN with a Very Wide...
# 3  Computer Science final year project ideas / su...
# 4  prove that the language L = { ww | w ∈ {a,b}* ...
#
#                                                 Tags AnswerCount CommentCount  \
# 0     <complexity-theory><p-vs-np><3-sat><colorings>           0            2
# 1  <algorithms><graphs><data-structures><optimiza...           0            2
# 2                <machine-learning><neural-networks>           0            2
# 3                                <complexity-theory>           0            5
# 4  <formal-languages><context-free><proof-techniq...           0            0
#
#   FavoriteCount          ClosedDate  CommunityOwnedDate ContentLicense
# 0          None 2023-08-28 01:29:50                None   CC BY-SA 4.0
# 1          None 2023-08-28 01:28:30                None   CC BY-SA 4.0
# 2          None 2023-08-27 00:34:40                None   CC BY-SA 4.0
# 3          None 2023-08-25 07:31:07                None   CC BY-SA 4.0
# 4          None 2023-08-20 23:15:09                None   CC BY-SA 4.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.9783551999999993

# %%
query = lambda: mongodb.Posts.find({"ClosedDate":{"$exists": True}}).sort('ClosedDate',pymongo.DESCENDING).limit(10)

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId AcceptedAnswerId ParentId  \
# 0  6551e8aedb0b505f45a7ab6b  161781           1             None     None
# 1  6551e8addb0b505f45a7a65d  160197           1             None     None
# 2  6551e8aedb0b505f45a7ab68  161778           1             None     None
# 3  6551e8aedb0b505f45a7ab3f  161733           1             None     None
# 4  6551e8aedb0b505f45a7ab28  161703           1             None     None
#
#              CreationDate  Score  ViewCount  \
# 0 2023-08-27 04:51:27.650     -2         39
# 1 2023-05-15 22:34:08.733      1         18
# 2 2023-08-26 16:23:33.213      0          9
# 3 2023-08-23 16:28:34.433     -3         36
# 4 2023-08-20 13:16:33.107      0         18
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>The algorithm assumes the graph is 3-colora...       162670  ...
# 1  <p>I'm working on implementing a puzzle board ...       160598  ...
# 2  <p>The input of my neural network consists of ...       162660  ...
# 3  <p>TL;DR: How can I make my final year project...       162599  ...
# 4  <p>I came across this question presented in a ...       162465  ...
#
#          LastActivityDate                                              Title  \
# 0 2023-08-27 04:53:58.727       Is this 3-colorability algorithm polynomial?
# 1 2023-05-15 22:34:08.733  generating solvable puzzles for a Double-Choco...
# 2 2023-08-26 16:23:33.213  What Model to Choose for a NN with a Very Wide...
# 3 2023-08-24 18:30:13.040  Computer Science final year project ideas / su...
# 4 2023-08-20 13:16:33.107  prove that the language L = { ww | w ∈ {a,b}* ...
#
#                                                 Tags AnswerCount CommentCount  \
# 0     [complexity-theory, p-vs-np, 3-sat, colorings]           0            2
# 1  [algorithms, graphs, data-structures, optimiza...           0            2
# 2                [machine-learning, neural-networks]           0            2
# 3                                [complexity-theory]           0            5
# 4  [formal-languages, context-free, proof-techniq...           0            0
#
#    FavoriteCount              ClosedDate CommunityOwnedDate  \
# 0           None 2023-08-28 01:29:50.107               None
# 1           None 2023-08-28 01:28:30.280               None
# 2           None 2023-08-27 00:34:39.767               None
# 3           None 2023-08-25 07:31:07.220               None
# 4           None 2023-08-20 23:15:08.920               None
#
#                                             Comments  \
# 0  [{'CommentId': 338296, 'Score': 0, 'Text': 'Yo...
# 1  [{'CommentId': 338294, 'Score': 0, 'Text': 'Cr...
# 2  [{'CommentId': 338283, 'Score': 0, 'Text': 'Cr...
# 3  [{'CommentId': 338243, 'Score': 2, 'Text': 'I ...
# 4                                                NaN
#
#                                            PostLinks
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'PostLinkId': 2998333, 'CreationDate': 2023-...
#
# [5 rows x 22 columns]

# %%
mongo_cost
# Out:
# 0.0007044999999976653

# %% [markdown]
# ### Select posts by tag

# %%
#Take 'cpu-pipelines' as an example
sql = '''
    SELECT p.*
    FROM Posts p
    JOIN post_tags pt
    ON p.Id = pt.PostId
    JOIN tags t
    ON pt.TagId = t.Id
    WHERE t.TagName = 'cpu-pipelines';
'''

# %%
sql_df, sql_cost = getSQLResult(sql)

# %%
sql_df.head()
# Out:
#       Id  PostTypeId  AcceptedAnswerId ParentId        CreationDate  \
# 0     73           1              76.0     None 2012-03-07 05:11:44
# 1   1936           1            6646.0     None 2012-05-19 20:49:42
# 2  19668           1           19681.0     None 2014-01-12 14:04:37
# 3  20093           1               NaN     None 2014-01-30 03:29:25
# 4  21924           1               NaN     None 2014-02-22 16:04:48
#
#   DeletionDate  Score  ViewCount  \
# 0         None     11        654
# 1         None      8       1866
# 2         None      5      12063
# 3         None      3       7085
# 4         None      0      11557
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I have observed that there are two differen...          NaN  ...
# 1  <p>I'm looking for some relatively simple exam...       1554.0  ...
# 2  <p>I'm a little confused about the difference ...      12774.0  ...
# 3  <p><strong>NOTE</strong>: Let me point out tha...       6569.0  ...
# 4  <p>I was trying to solve a question dealing wi...      14939.0  ...
#
#          LastEditDate    LastActivityDate  \
# 0 2012-03-07 05:32:21 2012-11-14 00:40:54
# 1 2012-05-19 21:12:40 2012-11-13 14:32:06
# 2 2014-01-13 07:08:01 2014-08-07 14:26:06
# 3 2014-01-30 14:48:47 2018-01-06 10:14:10
# 4 2014-03-27 18:36:41 2014-03-27 18:36:41
#
#                                                Title  \
# 0  Which kind of branch prediction is more import...
# 1  When do structural hazards occur in pipelined ...
# 2  Difference between memory access and write-bac...
# 3  How are the control signals derived in the MIP...
# 4               Execution time of an uneven pipeline
#
#                                      Tags AnswerCount CommentCount  \
# 0  <cpu-pipelines><computer-architecture>           2            1
# 1  <computer-architecture><cpu-pipelines>           1            0
# 2  <computer-architecture><cpu-pipelines>           3            2
# 3  <computer-architecture><cpu-pipelines>           1            4
# 4  <computer-architecture><cpu-pipelines>           3            1
#
#   FavoriteCount  ClosedDate  CommunityOwnedDate  ContentLicense
# 0           NaN         NaT                None    CC BY-SA 3.0
# 1           NaN         NaT                None    CC BY-SA 3.0
# 2           NaN         NaT                None    CC BY-SA 3.0
# 3           NaN         NaT                None    CC BY-SA 3.0
# 4           NaN         NaT                None    CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
sql_cost
# Out:
# 0.014892700000000758

# %%
query = lambda: mongodb.Posts.find({"Tags" : 'cpu-pipelines'})

# %%
mongo_df, mongo_cost = getMongoResult(query)

# %%
mongo_df.head()
# Out:
#                         _id  PostId  PostTypeId  AcceptedAnswerId ParentId  \
# 0  6551e8acdb0b505f45a61ac9      73           1              76.0     None
# 1  6551e8acdb0b505f45a62144    1936           1            6646.0     None
# 2  6551e8acdb0b505f45a64975   19668           1           19681.0     None
# 3  6551e8acdb0b505f45a64a9b   20093           1               NaN     None
# 4  6551e8addb0b505f45a64ceb   21924           1               NaN     None
#
#              CreationDate  Score  ViewCount  \
# 0 2012-03-07 05:11:43.907     11        654
# 1 2012-05-19 20:49:42.443      8       1866
# 2 2014-01-12 14:04:36.507      5      12063
# 3 2014-01-30 03:29:24.877      3       7085
# 4 2014-02-22 16:04:48.137      0      11557
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I have observed that there are two differen...          NaN  ...
# 1  <p>I'm looking for some relatively simple exam...       1554.0  ...
# 2  <p>I'm a little confused about the difference ...      12774.0  ...
# 3  <p><strong>NOTE</strong>: Let me point out tha...       6569.0  ...
# 4  <p>I was trying to solve a question dealing wi...      14939.0  ...
#
#          LastActivityDate                                              Title  \
# 0 2012-11-14 00:40:54.050  Which kind of branch prediction is more import...
# 1 2012-11-13 14:32:05.693  When do structural hazards occur in pipelined ...
# 2 2014-08-07 14:26:06.260  Difference between memory access and write-bac...
# 3 2018-01-06 10:14:09.823  How are the control signals derived in the MIP...
# 4 2014-03-27 18:36:40.790               Execution time of an uneven pipeline
#
#                                      Tags AnswerCount CommentCount  \
# 0  [cpu-pipelines, computer-architecture]           2            1
# 1  [computer-architecture, cpu-pipelines]           1            0
# 2  [computer-architecture, cpu-pipelines]           3            2
# 3  [computer-architecture, cpu-pipelines]           1            4
# 4  [computer-architecture, cpu-pipelines]           3            1
#
#    FavoriteCount  ClosedDate  CommunityOwnedDate  \
# 0            NaN         NaT                None
# 1            NaN         NaT                None
# 2            NaN         NaT                None
# 3            NaN         NaT                None
# 4            NaN         NaT                None
#
#                                             Comments PostLinks
# 0  [{'CommentId': 143, 'Score': 1, 'Text': 'Maybe...       NaN
# 1                                                NaN       NaN
# 2  [{'CommentId': 39958, 'Score': 0, 'Text': 'Whe...       NaN
# 3  [{'CommentId': 41065, 'Score': 0, 'Text': 'You...       NaN
# 4  [{'CommentId': 43358, 'Score': 1, 'Text': 'Wha...       NaN
#
# [5 rows x 22 columns]

# %%
mongo_cost
# Out:
# 8.289999999888664e-05
